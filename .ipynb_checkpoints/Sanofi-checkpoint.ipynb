# %%
import os
import pandas as pd
import numpy as np
import glob

# %%
import pandas as pd

file_path_list = []
# read in all files from
path = r'/Users/GuntherUlvanget/Dropbox/NADAC_downloads/SANOFI' # use your path
all_paths = glob.glob(path + "/2*")

# %%
#for loop this
#new_list = [expression(i) for i in old_list if filter(i)]
all_files = [glob.glob(i + "/*.xls*") for i in all_paths] 
#flatten the 
all_files = [item for sublist in all_files for item in sublist]
all_files
# Out:
# ['/Users/GuntherUlvanget/Dropbox/NADAC_downloads/SANOFI/2014/CA_March_2014.xls',
#  '/Users/GuntherUlvanget/Dropbox/NADAC_downloads/SANOFI/2014/NetSales2014_EN.xls',
#  '/Users/GuntherUlvanget/Dropbox/NADAC_downloads/SANOFI/2014/Q2_2014_Sales_EN.xls',
#  '/Users/GuntherUlvanget/Dropbox/NADAC_downloads/SANOFI/2014/Q3_2014_Sales_EN.xls',
#  '/Users/GuntherUlvanget/Dropbox/NADAC_downloads/SANOFI/2015/Sales_2015.xls',
#  '/Users/GuntherUlvanget/Dropbox/NADAC_downloads/SANOFI/2015/Sales_Q12015_EN.xls',
#  '/Users/GuntherUlvanget/Dropbox/NADAC_downloads/SANOFI/2015/Sales_Q22015.xls',
#  '/Users/GuntherUlvanget/Dropbox/NADAC_downloads/SANOFI/2015/Sales_Q32015.xls',
#  '/Users/GuntherUlvanget/Dropbox/NADAC_downloads/SANOFI/2016/2016_Q4_APPENDIX_Sales_GBU.xlsx',
#  '/Users/GuntherUlvanget/Dropbox/NADAC_downloads/SANOFI/2016/Sales_GBU_franchises_Q22016.xlsx',
#  '/Users/GuntherUlvanget/Dropbox/NADAC_downloads/SANOFI/2016/Sales_GBU_franchises_Q32016.xlsx',
#  '/Users/GuntherUlvanget/Dropbox/NADAC_downloads/SANOFI/2016/SalesGBUs_FranchisesQ12016.xlsx',
#  '/Users/GuntherUlvanget/Dropbox/NADAC_downloads/SANOFI/2017/2017_Sales_Q4_FY__EN.xlsx',
#  '/Users/GuntherUlvanget/Dropbox/NADAC_downloads/SANOFI/2017/Sales_GBU_franchises_Q12017.xlsx',
#  '/Users/GuntherUlvanget/Dropbox/NADAC_downloads/SANOFI/2017/Sales_Q2_H1_2017.xlsx',
#  '/Users/GuntherUlvanget/Dropbox/NADAC_downloads/SANOFI/2017/Sales_Q3_9M_2017.xlsx',
#  '/Users/GuntherUlvanget/Dropbox/NADAC_downloads/SANOFI/2018/2018_APPENDIX_SALES_EN.xlsx',
#  '/Users/GuntherUlvanget/Dropbox/NADAC_downloads/SANOFI/2018/2018_Appendix_sales_Q3.xlsx',
#  '/Users/GuntherUlvanget/Dropbox/NADAC_downloads/SANOFI/2018/2018_Q1Sales_EN.xlsx',
#  '/Users/GuntherUlvanget/Dropbox/NADAC_downloads/SANOFI/2018/2018_SALES_APPENDIX_EN.xlsx',
#  '/Users/GuntherUlvanget/Dropbox/NADAC_downloads/SANOFI/2019/2019_Appendix_sales_Q2.xlsx',
#  '/Users/GuntherUlvanget/Dropbox/NADAC_downloads/SANOFI/2019/2019_Appendix_sales_Q3_.xlsx',
#  '/Users/GuntherUlvanget/Dropbox/NADAC_downloads/SANOFI/2019/2019_Sales_Appendix_Q1_EN.xlsx']

# %%
df_list = []
sheet_name_dict = {all_files[i]: pd.ExcelFile(all_files[i]).sheet_names for i in 
                   range(len(all_files))}
#pd.ExcelFile('/Users/GuntherUlvanget/Dropbox/NADAC_downloads/SANOFI/2014/NetSales2014_EN.xls').sheet_names
sheet_name_dict
#type(xl.sheet_names)  # see all sheet names

#xl.parse(sheet_name)  # read a specific sheet to DataFrame
# Out:
# {'/Users/GuntherUlvanget/Dropbox/NADAC_downloads/SANOFI/2014/CA_March_2014.xls': ['YTD MARCH internet'],
#  '/Users/GuntherUlvanget/Dropbox/NADAC_downloads/SANOFI/2014/NetSales2014_EN.xls': ['FY 2014 Sales',
#   'Q4 2014 Sales'],
#  '/Users/GuntherUlvanget/Dropbox/NADAC_downloads/SANOFI/2014/Q2_2014_Sales_EN.xls': ['YTD June',
#   'QTD June'],
#  '/Users/GuntherUlvanget/Dropbox/NADAC_downloads/SANOFI/2014/Q3_2014_Sales_EN.xls': ['YTD September EN',
#   'Sept QTD EN'],
#  '/Users/GuntherUlvanget/Dropbox/NADAC_downloads/SANOFI/2015/Sales_2015.xls': ['Sales 2015  & Q4 2015'],
#  '/Users/GuntherUlvanget/Dropbox/NADAC_downloads/SANOFI/2015/Sales_Q12015_EN.xls': ['Sales Q1 2015'],
#  '/Users/GuntherUlvanget/Dropbox/NADAC_downloads/SANOFI/2015/Sales_Q22015.xls': ['Sales Q2 2015',
#   'Sales H1 2015'],
#  '/Users/GuntherUlvanget/Dropbox/NADAC_downloads/SANOFI/2015/Sales_Q32015.xls': ['9 MONTHS 2015',
#   'Q3 2015'],
#  '/Users/GuntherUlvanget/Dropbox/NADAC_downloads/SANOFI/2016/2016_Q4_APPENDIX_Sales_GBU.xlsx': ['APPENDIX EN'],
#  '/Users/GuntherUlvanget/Dropbox/NADAC_downloads/SANOFI/2016/Sales_GBU_franchises_Q22016.xlsx': ['Feuil1'],
#  '/Users/GuntherUlvanget/Dropbox/NADAC_downloads/SANOFI/2016/Sales_GBU_franchises_Q32016.xlsx': ['2016-APPENDIX EN'],
#  '/Users/GuntherUlvanget/Dropbox/NADAC_downloads/SANOFI/2016/SalesGBUs_FranchisesQ12016.xlsx': ['Feuil1'],
#  '/Users/GuntherUlvanget/Dropbox/NADAC_downloads/SANOFI/2017/2017_Sales_Q4_FY__EN.xlsx': ['SALES APPENDIX EN CLEAR'],
#  '/Users/GuntherUlvanget/Dropbox/NADAC_downloads/SANOFI/2017/Sales_GBU_franchises_Q12017.xlsx': ['Feuil1'],
#  '/Users/GuntherUlvanget/Dropbox/NADAC_downloads/SANOFI/2017/Sales_Q2_H1_2017.xlsx': ['H1 and Q2 2017 net sales'],
#  '/Users/GuntherUlvanget/Dropbox/NADAC_downloads/SANOFI/2017/Sales_Q3_9M_2017.xlsx': ['9M and Q3 2017 net sales'],
#  '/Users/GuntherUlvanget/Dropbox/NADAC_downloads/SANOFI/2018/2018_APPENDIX_SALES_EN.xlsx': ['Sales H1 and Q2 2018'],
#  '/Users/GuntherUlvanget/Dropbox/NADAC_downloads/SANOFI/2018/2018_Appendix_sales_Q3.xlsx': ['Sales 9M and Q3 2018'],
#  '/Users/GuntherUlvanget/Dropbox/NADAC_downloads/SANOFI/2018/2018_Q1Sales_EN.xlsx': ['Q1 2018'],
#  '/Users/GuntherUlvanget/Dropbox/NADAC_downloads/SANOFI/2018/2018_SALES_APPENDIX_EN.xlsx': ['Sales Q4 and FY 2018'],
#  '/Users/GuntherUlvanget/Dropbox/NADAC_downloads/SANOFI/2019/2019_Appendix_sales_Q2.xlsx': ['Feuil1',
#   'Feuil2',
#   'Feuil3'],
#  '/Users/GuntherUlvanget/Dropbox/NADAC_downloads/SANOFI/2019/2019_Appendix_sales_Q3_.xlsx': ['Feuil1',
#   'Feuil2',
#   'Feuil3'],
#  '/Users/GuntherUlvanget/Dropbox/NADAC_downloads/SANOFI/2019/2019_Sales_Appendix_Q1_EN.xlsx': ['Feuil1',
#   'Feuil2',
#   'Feuil3']}

# %%
for filename in all_files:
    
    df = pd.read_excel(filename, sheetname = index_col=None, header=0)
    df_list .append(df)

# %%
document_shapes = [df_list[i].shape for i in range(len(df_list))]
document_shapes
# Out:
# [(58, 16),
#  (59, 16),
#  (58, 16),
#  (58, 16),
#  (130, 16),
#  (60, 18),
#  (63, 17),
#  (65, 17),
#  (123, 22),
#  (129, 21),
#  (128, 22),
#  (68, 21),
#  (135, 21),
#  (62, 21),
#  (133, 21),
#  (132, 21),
#  (131, 21),
#  (130, 21),
#  (64, 24),
#  (130, 21),
#  (128, 21),
#  (127, 21),
#  (63, 21)]

# %%
li[2]
#frame = pd.concat(li,  ignore_index=True)
#frame
#glob.glob('.c*')
# Out:
#              H1 net sales\n(€ million)       Total     Var. (TCC)  \
# 0                               Lantus   3005000000       0.14889
# 1                               Apidra    152000000       0.19403
# 2                               Amaryl    182000000     0.0207254
# 3                              Insuman     65000000     0.0461538
# 4                              Lyxumia     11000000            10
# 5                             Diabetes   3450000000      0.147328
# 6                             Taxotere    136000000     -0.328829
# 7                          Jevtana (*)    132000000      0.283019
# 8                            Eloxatine     93000000     -0.151261
# 9                        Thymoglobulin    106000000       0.15625
# 10                         Mozobil (*)     51000000     0.0196078
# 11                         Zaltrap (*)     31000000          0.28
# 12                      Other Oncology    131000000         0.088
# 13                            Oncology    680000000    -0.0362903
# 14                             Aubagio    175000000       2.45283
# 15                            Lemtrada     11000000             -
# 16                            Cerezyme    343000000     0.0789474
# 17                             Myozyme    254000000     0.0909091
# 18                           Fabrazyme    221000000      0.284153
# 19                          Aldurazyme     86000000      0.166667
# 20        Other Rare Diseases products    119000000     0.0333333
# 21                             Genzyme   1209000000       0.25442
# 22                              Plavix    912000000     0.0434783
# 23                             Lovenox    837000000    0.00925926
# 24                             Aprovel    372000000     -0.192067
# 25                 Renagel And Renvela    309000000     -0.066474
# 26                             Allegra    119000000      -0.46371
# 27                             Stilnox    151000000     -0.150259
# 28                            Depakine    191000000    -0.0334928
# 29               Synvisc / Synvisc One    163000000    -0.0604396
# 30                             Tritace    143000000     -0.056962
# 31                          Multaq (*)    139000000     0.0992366
# 32                               Lasix     81000000     0.0361446
# 33                            Targocid     75000000     -0.113636
# 34                              Orudis     83000000      0.260274
# 35                           Cordarone     65000000    -0.0138889
# 36                              Xatral     47000000    -0.0392157
# 37                             Actonel     41000000     -0.134615
# 38              Auvi-Q / Allerject (*)     26000000      0.421053
# 39                      Other Rx Drugs   1836000000    -0.0979935
# 40                Total Other Rx Drugs   5590000000    -0.0669403
# 41                 Consumer Healthcare   1701000000      0.193506
# 42                            Generics    887000000      0.319502
# 43                     Pharmaceuticals  13517000000     0.0593847
# 44                     Polio Pertussis    495000000    -0.0657194
# 45                  Influenza Vaccines    194000000       0.19186
# 46                 Meningite/Pneumonie    171000000     -0.108374
# 47              Adult Booster Vaccines    164000000     -0.177033
# 48  Travel And Other Andemics Vaccines    178000000      0.110465
# 49                      Other Vaccines    144000000     0.0869565
# 50                           Vaccines    1346000000    -0.0219629
# 51                   Fipronil products    340000000    -0.0247253
# 52                             Nexgard     58000000             -
# 53                            Vaccines    334000000    -0.0249307
# 54                 Avermectin products    212000000    -0.0857143
# 55                              Others    110000000     0.0176991
# 56                       Animal Health   1054000000     0.0221607
# 57                         Total Group  15917000000     0.0494957
#
#    Var. (publiées)  Unnamed: 4  Western Europe  Var. (TCC).1  Unnamed: 7  \
# 0        0.0939206         NaN       421000000     0.0501253         NaN
# 1         0.134328         NaN        47000000         0.175         NaN
# 2       -0.0569948         NaN        10000000     -0.166667         NaN
# 3                0         NaN        40000000     -0.111111         NaN
# 4               10         NaN         7000000             6         NaN
# 5        0.0907366         NaN       554000000     0.0635838         NaN
# 6        -0.387387         NaN         8000000     -0.428571         NaN
# 7         0.245283         NaN        72000000      0.469388         NaN
# 8        -0.218487         NaN         2000000     -0.333333         NaN
# 9         0.104167         NaN        16000000     0.0666667         NaN
# 10               0         NaN        16000000             0         NaN
# 11            0.24         NaN        16000000          2.75         NaN
# 12           0.048         NaN        29000000     0.0357143         NaN
# 13      -0.0860215         NaN       159000000      0.224806         NaN
# 14         2.30189         NaN        38000000             -         NaN
# 15               -         NaN        10000000             -         NaN
# 16      0.00292398         NaN       119000000     0.0530973         NaN
# 17       0.0495868         NaN       130000000    -0.0444444         NaN
# 18         0.20765         NaN        53000000      0.292683         NaN
# 19        0.102564         NaN        32000000     0.0333333         NaN
# 20     -0.00833333         NaN        21000000           0.1         NaN
# 21        0.187623         NaN       403000000      0.188791         NaN
# 22      -0.0328738         NaN       116000000     -0.134328         NaN
# 23        -0.03125         NaN       451000000     0.0514019         NaN
# 24       -0.223382         NaN       106000000     -0.450777         NaN
# 25       -0.106936         NaN        65000000    -0.0441176         NaN
# 26       -0.520161         NaN         6000000             0         NaN
# 27       -0.217617         NaN        21000000             0         NaN
# 28      -0.0861244         NaN        67000000             0         NaN
# 29       -0.104396         NaN        14000000      0.166667         NaN
# 30      -0.0949367         NaN        65000000     -0.057971         NaN
# 31       0.0610687         NaN        22000000      0.047619         NaN
# 32      -0.0240964         NaN        40000000     0.0810811         NaN
# 33       -0.147727         NaN        41000000    -0.0697674         NaN
# 34        0.136986         NaN        10000000     -0.230769         NaN
# 35      -0.0972222         NaN        12000000    -0.0769231         NaN
# 36      -0.0784314         NaN        19000000             0         NaN
# 37       -0.211538         NaN         9000000     -0.181818         NaN
# 38        0.368421         NaN         1000000          -0.5         NaN
# 39       -0.143257         NaN       774000000    -0.0708283         NaN
# 40       -0.117461         NaN      1839000000    -0.0768844         NaN
# 41        0.104545         NaN       361000000             0         NaN
# 42        0.226833         NaN       275000000    -0.0284698         NaN
# 43    -0.000369768         NaN      3591000000   -0.00967118         NaN
# 44       -0.120782         NaN        12000000     -0.294118         NaN
# 45        0.127907         NaN         1000000             0         NaN
# 46       -0.157635         NaN               0            -1         NaN
# 47       -0.215311         NaN        16000000     -0.564103         NaN
# 48       0.0348837         NaN        13000000         0.625         NaN
# 49       0.0434783         NaN         1000000             -         NaN
# 50      -0.0761839         NaN        43000000     -0.367647         NaN
# 51      -0.0659341         NaN       112000000             0         NaN
# 52               -         NaN         4000000             -         NaN
# 53      -0.0747922         NaN        88000000     -0.032967         NaN
# 54       -0.134694         NaN        28000000    -0.0357143         NaN
# 55      -0.0265487         NaN        40000000             0         NaN
# 56      -0.0267775         NaN       272000000             0         NaN
# 57     -0.00902752         NaN      3906000000    -0.0151592         NaN
#
#     United States  Var. (TCC).2  Unnamed: 10  Emerging Markets  Var. (TCC).3  \
# 0      1986000000      0.174504          NaN         468000000      0.169683
# 1        55000000      0.163265          NaN          35000000           0.3
# 2         1000000             0          NaN         142000000      0.115942
# 3         1000000             0          NaN          24000000      0.421053
# 4               0             -          NaN           1000000             -
# 5      2043000000      0.174009          NaN         671000000      0.174603
# 6         5000000     -0.833333          NaN          75000000     -0.254545
# 7        42000000      0.047619          NaN          17000000      0.357143
# 8         1000000     -0.933333          NaN          59000000    -0.0307692
# 9        50000000          0.04          NaN          35000000      0.541667
# 10       27000000             0          NaN           6000000           0.2
# 11       14000000          -0.3          NaN           2000000             1
# 12       78000000         0.125          NaN          15000000      0.133333
# 13      217000000     -0.124514          NaN         209000000     -0.034188
# 14      131000000       1.58491          NaN           3000000             -
# 15              0             -          NaN                 0             -
# 16       90000000     0.0681818          NaN         115000000      0.145299
# 17       64000000      0.116667          NaN          46000000           0.5
# 18      106000000       0.14433          NaN          36000000      0.708333
# 19       16000000      0.142857          NaN          31000000      0.296296
# 20       40000000         -0.16          NaN          25000000           0.5
# 21      447000000      0.290055          NaN         256000000      0.327273
# 22        1000000          -0.8          NaN         426000000     0.0611765
# 23       61000000     -0.340206          NaN         283000000     0.0687285
# 24        9000000           0.5          NaN         201000000      0.014218
# 25      202000000     -0.105932          NaN          33000000        0.1875
# 26              0             -          NaN           3000000         -0.95
# 27       34000000     -0.102564          NaN          32000000             0
# 28              0             -          NaN         117000000    -0.0518519
# 29      127000000    -0.0896552          NaN          17000000      0.266667
# 30              0             -          NaN          74000000    -0.0357143
# 31      112000000      0.103774          NaN           4000000          0.25
# 32        1000000             0          NaN          25000000          0.16
# 33              0             -          NaN          31000000     -0.128205
# 34              0             -          NaN          71000000       0.37931
# 35              0             -          NaN          36000000      0.025641
# 36              0            -1          NaN          27000000     0.0344828
# 37              0             -          NaN          21000000         -0.08
# 38       21000000      0.466667          NaN                 0             -
# 39      197000000     -0.191406          NaN         691000000    -0.0759804
# 40      765000000     -0.120044          NaN        2092000000    -0.0206718
# 41      378000000      0.204268          NaN         869000000      0.355556
# 42       66000000      -0.35514          NaN         528000000      0.846875
# 43     3916000000     0.0817893          NaN        4625000000      0.146874
# 44      166000000      0.406504          NaN         241000000     -0.182692
# 45       21000000           1.1          NaN         160000000      0.142857
# 46      131000000      0.123967          NaN          37000000     -0.460526
# 47      123000000    -0.0915493          NaN          19000000     -0.047619
# 48       46000000           0.2          NaN          94000000     0.0309278
# 49      132000000     0.0859375          NaN           5000000             0
# 50      619000000       0.14539          NaN         556000000     -0.104704
# 51      164000000    -0.0899471          NaN          46000000      0.106383
# 52       53000000             -          NaN                 0             -
# 53       72000000    -0.0131579          NaN         166000000    -0.0324324
# 54      124000000     -0.127517          NaN          25000000             0
# 55       36000000     -0.097561          NaN          27000000      0.347826
# 56      449000000      0.032967          NaN         264000000      0.024735
# 57     4984000000     0.0846362          NaN        5445000000      0.109688
#
#     Unnamed: 13  Rest of the World  Var. (TCC).4
# 0           NaN          130000000     0.0425532
# 1           NaN           15000000      0.133333
# 2           NaN           29000000     -0.238095
# 3           NaN                  0             -
# 4           NaN            3000000             -
# 5           NaN          182000000     0.0353535
# 6           NaN           48000000     -0.205882
# 7           NaN            1000000             0
# 8           NaN           31000000    -0.0277778
# 9           NaN            5000000     -0.142857
# 10          NaN            2000000             0
# 11          NaN           -1000000             -
# 12          NaN            9000000          -0.1
# 13          NaN           95000000     -0.129032
# 14          NaN            3000000             -
# 15          NaN            1000000             -
# 16          NaN           19000000    -0.0833333
# 17          NaN           14000000      0.307692
# 18          NaN           26000000      0.428571
# 19          NaN            7000000      0.285714
# 20          NaN           33000000       0.03125
# 21          NaN          103000000      0.185567
# 22          NaN          369000000     0.0976253
# 23          NaN           42000000    -0.0208333
# 24          NaN           56000000      -0.15942
# 25          NaN            9000000          -0.1
# 26          NaN          110000000     -0.318681
# 27          NaN           64000000     -0.252525
# 28          NaN            7000000             0
# 29          NaN            5000000          -0.4
# 30          NaN            4000000          -0.4
# 31          NaN            1000000             -
# 32          NaN           15000000          -0.2
# 33          NaN            3000000     -0.333333
# 34          NaN            2000000             0
# 35          NaN           17000000         -0.05
# 36          NaN            1000000            -1
# 37          NaN           11000000       -0.1875
# 38          NaN            4000000             1
# 39          NaN          174000000     -0.168067
# 40          NaN          894000000     -0.102334
# 41          NaN           93000000      -0.19084
# 42          NaN           18000000           0.4
# 43          NaN         1385000000    -0.0738535
# 44          NaN           76000000     -0.225225
# 45          NaN           12000000     0.0714286
# 46          NaN            3000000      0.333333
# 47          NaN            6000000     -0.142857
# 48          NaN           25000000      0.111111
# 49          NaN            6000000          0.25
# 50          NaN          128000000     -0.120482
# 51          NaN           18000000      0.176471
# 52          NaN            1000000             -
# 53          NaN            8000000      0.111111
# 54          NaN           35000000        -0.025
# 55          NaN            7000000         -0.25
# 56          NaN           69000000      0.027027
# 57          NaN         1582000000    -0.0739969

# %%
files_2014 = os.listdir("/Users/GuntherUlvanget/Dropbox/NADAC_downloads/SANOFI/2014")

# %%
files_2015 = os.listdir("/Users/GuntherUlvanget/Dropbox/NADAC_downloads/SANOFI/2015")
files_2016 = os.listdir("/Users/GuntherUlvanget/Dropbox/NADAC_downloads/SANOFI/2016")
files_2017 = os.listdir("/Users/GuntherUlvanget/Dropbox/NADAC_downloads/SANOFI/2017")
files_2018 = os.listdir("/Users/GuntherUlvanget/Dropbox/NADAC_downloads/SANOFI/2018")
files_2019 = os.listdir("/Users/GuntherUlvanget/Dropbox/NADAC_downloads/SANOFI/2019")

# %%
pd.read_excel(files_2014[0])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-c75d6c8d6965> in <module>
# ----> 1 pd.read_excel(files_2014[0])
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     186                 else:
#     187                     kwargs[new_arg_name] = new_arg_value
# --> 188             return func(*args, **kwargs)
#     189         return wrapper
#     190     return _deprecate_kwarg
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     186                 else:
#     187                     kwargs[new_arg_name] = new_arg_value
# --> 188             return func(*args, **kwargs)
#     189         return wrapper
#     190     return _deprecate_kwarg
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/excel.py in read_excel(io, sheet_name, header, names, index_col, parse_cols, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, verbose, parse_dates, date_parser, thousands, comment, skip_footer, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     348
#     349     if not isinstance(io, ExcelFile):
# --> 350         io = ExcelFile(io, engine=engine)
#     351
#     352     return io.parse(
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/excel.py in __init__(self, io, engine)
#     651         self._io = _stringify_path(io)
#     652
# --> 653         self._reader = self._engines[engine](self._io)
#     654
#     655     def __fspath__(self):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/excel.py in __init__(self, filepath_or_buffer)
#     422             self.book = xlrd.open_workbook(file_contents=data)
#     423         elif isinstance(filepath_or_buffer, compat.string_types):
# --> 424             self.book = xlrd.open_workbook(filepath_or_buffer)
#     425         else:
#     426             raise ValueError('Must explicitly set engine if not passing in'
#
# ~/anaconda3/lib/python3.7/site-packages/xlrd/__init__.py in open_workbook(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows)
#     109     else:
#     110         filename = os.path.expanduser(filename)
# --> 111         with open(filename, "rb") as f:
#     112             peek = f.read(peeksz)
#     113     if peek == b"PK\x03\x04": # a ZIP file
#
# FileNotFoundError: [Errno 2] No such file or directory: 'CA_March_2014.xls'

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-ece8b328c0c0> in <module>
# ----> 1 setwd("/Users/GuntherUlvanget/Dropbox/NADAC_downloads/SANOFI/2014")
#
# NameError: name 'setwd' is not defined
